# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy 
import pandas as pd
from scipy import linalg as la
import seaborn as sns
# %precision 4
np.set_printoptions(suppress=True)

# %%
N=1000
x1 = np.random.normal(loc=0, scale=1, size=N)

x2 = x1 + np.random.normal(loc=0, scale=3, size=N)

x3 = 2*x1+x2

# %%
X = np.vstack((x1,x2,x3)).T
X
# Out:
# array([[ 0.8686, -0.5479,  1.1893],
#        [ 1.4752, -2.714 ,  0.2365],
#        [-0.6924,  2.6429,  1.2581],
#        ...,
#        [ 0.0761,  2.4419,  2.5941],
#        [ 0.1994,  2.8366,  3.2354],
#        [-0.1295,  0.2419, -0.017 ]])

# %%
sns.pairplot(pd.DataFrame(X))

# %%
cov = np.cov(X, rowvar=False)
print(cov)
# Out:
# [[ 1.0021  1.0579  3.062 ]
#  [ 1.0579  9.789  11.9047]
#  [ 3.062  11.9047 18.0288]]

# %%
l, V = la.eig(cov)
print(np.real_if_close(l), '\n')
print(V)
# Out:
# [26.8801  0.      1.9397]
#
# [[-0.1194 -0.8165  0.5649]
#  [-0.5724 -0.4082 -0.7111]
#  [-0.8112  0.4082  0.4187]]

# %%
U, spectrum, Vt = np.linalg.svd(X.T)

l_svd = spectrum**2/(N-1)
V_svd = U

print(l_svd, '\n')
print(V_svd, '\n')
# Out:
# [26.9771  1.9409  0.    ]
#
# [[-0.1196  0.5648 -0.8165]
#  [-0.5721 -0.7113 -0.4082]
#  [-0.8114  0.4183  0.4082]]

# %%
print('Percentage of dataset variability')
trc = np.real_if_close(l).sum()
trc_svd = np.real_if_close(l_svd).sum()

print('Princial component percentage variability', np.real_if_close(l).max()/trc)
print('Princial component percentage variability (SVD)', np.real_if_close(l_svd).max()/trc_svd)
# Out:
# Percentage of dataset variability
# Princial component percentage variability 0.9326940119646101
# Princial component percentage variability (SVD) 0.9328834420497784

# %%
f, ax = plt.subplots(1,1)
ax.scatter(X.T[0],X.T[2])

Xp= np.dot(V.T, X.T)
ax.scatter(Xp[0, :], Xp[2, :])
plt.grid(True)

# %%
diag = np.diag(np.real_if_close(l))
print(diag)
print('Dimension reduction from 3 to 2 is obtained by taking the first and third eighvector as basis vector')
# Out:
# [[26.8801  0.      0.    ]
#  [ 0.      0.      0.    ]
#  [ 0.      0.      1.9397]]
# Dimension reduction from 3 to 2 is obtained by taking the first and third eighvector as basis vector

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
noise1 = np.random.multivariate_normal(np.zeros(10), 1/50 * np.diag(np.ones(10)), N)
no1 = np.sum(noise1, axis=1)

noise2 = np.random.multivariate_normal(np.zeros(10), 1/50 * np.diag(np.ones(10)), N)
no2 = np.sum(noise2, axis=1)

noise3 = np.random.multivariate_normal(np.zeros(10), 1/50 * np.diag(np.ones(10)), N)
no3 = np.sum(noise3, axis=1)

print(noise1.shape)
# Out:
# (1000, 10)

# %%
x1_ = x1 + no1
x2_ = x2 + no2
x3_ = x3 + no3

# %%
X_ = np.vstack((x1_,x2_,x3_)).T
print(X_)
# Out:
# [[ 0.4786 -0.3741  1.3275]
#  [ 2.0053 -2.5564  0.3083]
#  [-1.0095  2.7651  0.2593]
#  ...
#  [ 0.0421  2.899   1.8643]
#  [ 0.8768  3.4948  2.599 ]
#  [ 0.3133  0.5374  0.3446]]

# %%
sns.pairplot(pd.DataFrame(X_))

# %%
cov = np.cov(X, rowvar=False)
l, V = la.eig(cov)
print(cov)
# Out:
# [[ 1.0021  1.0579  3.062 ]
#  [ 1.0579  9.789  11.9047]
#  [ 3.062  11.9047 18.0288]]

# %%
U, spectrum, Vt = np.linalg.svd(X_.T)

l_svd = spectrum**2/(N-1)
v_svd = U

print(l_svd, '\n')
print(V_svd)
# Out:
# [26.9747  2.0898  0.1952]
#
# [[-0.1196  0.5648 -0.8165]
#  [-0.5721 -0.7113 -0.4082]
#  [-0.8114  0.4183  0.4082]]

# %%
tr_svd = l_svd.sum()
print(f'Maximum pca percentege (SVD): {l_svd.max()/tr_svd}')
# Out:
# Maximum pca percentege (SVD): 0.9219075540830031

# %%
Xp_ = np.dot(V_svd.T, X_.T)
plt.scatter(X_.T[0], X_.T[2])
plt.scatter(Xp_[0], Xp_[2])
plt.grid(True)
plt.show()

# %%
sns.pairplot(pd.DataFrame(X_))

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
# Out:
# --2022-12-22 12:13:15--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252, 52.35.62.125, 128.200.200.146
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1477391 (1.4M) [application/x-httpd-php]
# Saving to: ‘/home/vepe/data/magic04.data.17’
#
# magic04.data.17     100%[===================>]   1.41M  1.12MB/s    in 1.3s
#
# 2022-12-22 12:13:17 (1.12 MB/s) - ‘/home/vepe/data/magic04.data.17’ saved [1477391/1477391]
#
# --2022-12-22 12:13:17--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252, 52.35.62.125, 128.200.200.146
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5400 (5.3K) [application/x-httpd-php]
# Saving to: ‘/home/vepe/data/magic04.names.8’
#
# magic04.names.8     100%[===================>]   5.27K  --.-KB/s    in 0.001s
#
# 2022-12-22 12:13:18 (4.42 MB/s) - ‘/home/vepe/data/magic04.names.8’ saved [5400/5400]
